# %%
import spotipy
from pprint import pprint
import pandas as pd
import sys

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
cid = '41467bca65514079952e212808b80b3e'
secret = '97133de652814ffebb4d5eae856a315e'
client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
# run this to get playlist names and ids:
playlists = sp.user_playlists('ka2hb56cdiqneaqk9nfqcc97o')

# %%
pprint(playlists)
# Out:
# {'href': 'https://api.spotify.com/v1/users/ka2hb56cdiqneaqk9nfqcc97o/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#             'description': '',
#             'external_urls': {'spotify': 'https://open.spotify.com/playlist/61xDTMU3FQqEQOYs6KEbiJ'},
#             'href': 'https://api.spotify.com/v1/playlists/61xDTMU3FQqEQOYs6KEbiJ',
#             'id': '61xDTMU3FQqEQOYs6KEbiJ',
#             'images': [{'height': 640,
#                         'url': 'https://mosaic.scdn.co/640/ab67616d0000b27374894cb724cd98700a9757dfab67616d0000b27389c5c957f376e8c87ed23dccab67616d0000b273ad75bcb568d262601228c92bab67616d0000b273d5a006912e073417c09a50be',
#                         'width': 640},
#                        {'height': 300,
#                         'url': 'https://mosaic.scdn.co/300/ab67616d0000b27374894cb724cd98700a9757dfab67616d0000b27389c5c957f376e8c87ed23dccab67616d0000b273ad75bcb568d262601228c92bab67616d0000b273d5a006912e073417c09a50be',
# ...

# %%
# run this to take a playlist and id and convert it to a dataframe of song ids and attributes:
# playlist
playlist = sp.user_playlist("cynthia❤️", "2k4o5yyJTOHnubGHE7c0F6") 
songs = playlist["tracks"]["items"] 
ids = [] 
for i in range(len(songs)): 
    ids.append(songs[i]["track"]["id"]) 
features = sp.audio_features(ids) 
df = pd.DataFrame(features)

# %%
pprint(features)
# Out:
# [{'acousticness': 0.233,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/39Yp9wwQiSRIDOvrVg7mbk',
#   'danceability': 0.716,
#   'duration_ms': 165978,
#   'energy': 0.537,
#   'id': '39Yp9wwQiSRIDOvrVg7mbk',
#   'instrumentalness': 0,
#   'key': 0,
#   'liveness': 0.157,
#   'loudness': -7.648,
#   'mode': 0,
#   'speechiness': 0.0514,
#   'tempo': 129.979,
#   'time_signature': 4,
#   'track_href': 'https://api.spotify.com/v1/tracks/39Yp9wwQiSRIDOvrVg7mbk',
#   'type': 'audio_features',
#   'uri': 'spotify:track:39Yp9wwQiSRIDOvrVg7mbk',
#   'valence': 0.28},
#  {'acousticness': 0.256,
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Dv1eDb0MEgF93GpLXlucZ',
#   'danceability': 0.787,
#   'duration_ms': 237893,
#   'energy': 0.673,
#   'id': '3Dv1eDb0MEgF93GpLXlucZ',
#   'instrumentalness': 3.57e-06,
#   'key': 11,
#   'liveness': 0.0904,
#   'loudness': -4.577,
#   'mode': 0,
#   'speechiness': 0.158,
#   'tempo': 110.962,
#   'time_signature': 4,
# ...

# %%
pprint(songs)
# Out:
# [{'added_at': '2020-04-24T04:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                'href': 'https://api.spotify.com/v1/users/',
#                'id': '',
#                'type': 'user',
#                'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2PaZWGu5T5nHjY2xxAkFsT'},
#                                    'href': 'https://api.spotify.com/v1/artists/2PaZWGu5T5nHjY2xxAkFsT',
#                                    'id': '2PaZWGu5T5nHjY2xxAkFsT',
#                                    'name': 'THE SCOTTS',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2PaZWGu5T5nHjY2xxAkFsT'},
# ...

# %%
pprint(playlist)
# Out:
# {'collaborative': False,
#  'description': 'Doja Cat is on top of the Hottest 50!',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DXcBWIGoYBM5M'},
#  'followers': {'href': None, 'total': 26227230},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DXcBWIGoYBM5M?additional_types=track',
#  'id': '37i9dQZF1DXcBWIGoYBM5M',
#  'images': [{'height': None,
#              'url': 'https://i.scdn.co/image/ab67706f00000002833f073b13d274032f1bbed2',
#              'width': None}],
#  'name': "Today's Top Hits",
#  'owner': {'display_name': 'Spotify',
#            'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#            'href': 'https://api.spotify.com/v1/users/spotify',
#            'id': 'spotify',
#            'type': 'user',
#            'uri': 'spotify:user:spotify'},
#  'primary_color': '#C3F0C8',
#  'public': True,
#  'snapshot_id': 'MTU4NzcwMDg2MCwwMDAwMDNlNjAwMDAwMTcxYWE1ODg1ZmIwMDAwMDE3MWE5OWFlMDAw',
# ...

# %%
df.head(50)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.527   0.804   10    -4.168     1       0.0358      0.010400
# 1         0.607   0.588    0    -7.619     1       0.0331      0.625000
# 2         0.549   0.865    1    -3.486     0       0.0625      0.000482
# 3         0.567   0.644    6    -8.552     0       0.0322      0.438000
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.00000    0.1050   0.2210  107.486  audio_features
# 1           0.00131    0.1030   0.5680  135.517  audio_features
# 2           0.00000    0.0512   0.4340  140.017  audio_features
# 3           0.15400    0.0896   0.0655  146.681  audio_features
#
#                        id                                   uri  \
# 0  4lY95OMGb9WxP6IYut64ir  spotify:track:4lY95OMGb9WxP6IYut64ir
# 1  6aeNuqAB8YFxVPWkI7ffmm  spotify:track:6aeNuqAB8YFxVPWkI7ffmm
# 2  1KdGSnUj7Zr1XdTbyuSr7T  spotify:track:1KdGSnUj7Zr1XdTbyuSr7T
# ...

# %%
pprint(songs)
# Out:
# [{'added_at': '2020-04-24T04:01:00Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#                'href': 'https://api.spotify.com/v1/users/',
#                'id': '',
#                'type': 'user',
#                'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#                       'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2PaZWGu5T5nHjY2xxAkFsT'},
#                                    'href': 'https://api.spotify.com/v1/artists/2PaZWGu5T5nHjY2xxAkFsT',
#                                    'id': '2PaZWGu5T5nHjY2xxAkFsT',
#                                    'name': 'THE SCOTTS',
#                                    'type': 'artist',
#                                    'uri': 'spotify:artist:2PaZWGu5T5nHjY2xxAkFsT'},
# ...

# %%
df.head(50)

# %%
if len(sys.argv) > 1:
    search_str = sys.argv[1]
else:
    search_str = 'Gotye'

result = sp.search(search_str)
pprint(result)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=-f&type=track&offset=0&limit=10',
#             'items': [{'album': {'album_type': 'single',
#                                  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7uaIm6Pw7xplS8Dy06V6pT'},
#                                               'href': 'https://api.spotify.com/v1/artists/7uaIm6Pw7xplS8Dy06V6pT',
#                                               'id': '7uaIm6Pw7xplS8Dy06V6pT',
#                                               'name': 'Trevor Daniel',
#                                               'type': 'artist',
#                                               'uri': 'spotify:artist:7uaIm6Pw7xplS8Dy06V6pT'}],
#                                  'available_markets': ['AD',
#                                                        'AE',
#                                                        'AR',
#                                                        'AT',
# ...

# %%
playlist = sp.user_playlist("Spotify", "PLAYLIST ID") 

songs = playlist["tracks"]["items"] 
tracks = playlist["tracks"]

ids = [] 
while tracks['next']:
    tracks = sp.next(tracks)
    for item in tracks["items"]:
        if (item['track']['id'] is not None):
            ids.append(item['track']['id'])


features = []
for i in range(0,len(ids),50):    
    audio_features = sp.audio_features(ids[i:i+50])
    for track in audio_features:
        features.append(track)
